# %% [markdown]
# # Hand-in 3, Part 2: Data Modeling
#
# In this part you will take the csv file "reduced_field_data.csv" from Part 1, and use it to estimate the line criticality indices.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Score function
#
# Below is a scoring function we have written for you. The output of this function is a score of how well your procedure is doing. Higher scores are worse!
#
# As you can see, it penalizes heavily when you don't predict accurately values when they are being overloaded, i.e. false negatives.

# %%
def score_func(y_est, y_real):
    """
        This function takes your estimates y_est and
        scores them against the real data y_real.
        You should use this function to show how good your estimation method is.
    """
    # Square deviation
    sqr_err = np.sum(((y_est - y_real)**2).sum())
    # Penalty for not estimating a critical value above 0.95 when it occurs.
    false_negative = np.sum(np.where(np.logical_and(y_est < 0.95, y_real > 0.95), 10*np.sqrt(np.abs((y_est - y_real))), 0).sum())
    return sqr_err + false_negative

# %% [markdown]
# ## Load and clean data
#
# Load your data from the previous exercise as well as the criticality data.

# %%
# Data is loaded here
fdata = {}
cdata = {}
fdata['raw'] = pd.read_csv("reduced_field_data.csv", index_col=0)
cdata['raw'] = pd.read_csv("./Handin3_data/flow_criticality_data.csv", index_col=0)

# Data is cleaned here
import missingno as msno

indexes = fdata['raw'].index.tolist()
cdata['fixed'] = cdata['raw'].loc[indexes]

# Standardize data
fdata['std'] = (fdata['raw'] - fdata['raw'].mean()) / (fdata['raw'].max() - fdata['raw'].min())
cdata['std'] = (cdata['fixed'] - cdata['fixed'].mean()) / (cdata['fixed'].max() - cdata['fixed'].min())

print('Shape of data:\n\nField data:\t\t{0}\nCritical data:\t\t{1}\nCritical data fixed:\t{2}'.format(fdata['std'].shape, cdata['raw'].shape, cdata['std'].shape))
# Out:
# Shape of data:
#
# Field data:		(8311, 20)
# Critical data:		(8784, 10)
# Critical data fixed:	(8311, 10)

# %%
# Check data for N/A after standardization
print("Field data:\t{}\tN/A's\nCritical data:\t{}\tN/A's".format(fdata['std'].isnull().sum().sum(), cdata['std'].isnull().sum().sum()))

# Overview of dataframe before/after standardization
print("\nDataset before standardization:\n\nField data:\n{}\n\nCritical data:\n{}".format(fdata['raw'].head(), cdata['fixed'].head()))
print("\n\nDataset after standardization:\nFalse = Not N/A\nTrue = N/A\n\nField data:\n{}\n\nCritical data\n{}".format(fdata['std'].head(), cdata['std'].head()))

# Clean data for N/A's
fdata['std_no_nan'] = fdata['std'].dropna(axis=1)
print("\nField data after N/A dropped:\n{}\n\nColumns removed in field data:\n{}".format(fdata['std_no_nan'].head(), list(set(fdata['std']) - set(fdata['std_no_nan']))))
# Out:
# Field data:	24933	N/A's
# Critical data:	0	N/A's
#
# Dataset before standardization:
#
# Field data:
#                      load_node_153  prod_gen_12  renew_node_24  prod_gen_31  \
# time
# 2012-01-01 00:00:00        55.0930          0.0     153.470195        146.0
# 2012-01-01 01:00:00        51.3680          0.0     146.519552        146.0
# 2012-01-01 02:00:00        48.0104          0.0     138.456806        146.0
# 2012-01-01 03:00:00        45.6761          0.0     102.313463        146.0
# 2012-01-01 04:00:00        44.6987          0.0      77.569175        146.0
#
#                      export_node_108  prod_gen_14  prod_gen_34  prod_gen_1  \
# time
# 2012-01-01 04:00:00      -0.360383    -0.140735      -0.171040     0.649443
#
#                      export_node_108  prod_gen_14  prod_gen_34  prod_gen_1  \
# time
# 2012-01-01 00:00:00        -0.042117          NaN     0.647768         NaN
# 2012-01-01 01:00:00        -0.046702          NaN     0.647768         NaN
# 2012-01-01 02:00:00        -0.045351          NaN     0.647768         NaN
# 2012-01-01 03:00:00        -0.035143          NaN     0.647768         NaN
# 2012-01-01 04:00:00        -0.010547          NaN     0.647768         NaN
#
#                      prod_gen_49  prod_gen_22  prod_gen_29  load_node_16  \
# time
# 2012-01-01 00:00:00          NaN     0.631226     0.650876     -0.033708
# 2012-01-01 01:00:00          NaN     0.631226     0.650876     -0.073562
# 2012-01-01 02:00:00          NaN     0.631226     0.650876     -0.119932
# 2012-01-01 03:00:00          NaN     0.631226     0.650876     -0.192934
# 2012-01-01 04:00:00          NaN     0.631226     0.650876     -0.249650
#
#                      prod_gen_2  renew_node_143  renew_node_153  prod_gen_7  \
# time
# 2012-01-01 00:00:00   -0.026126       -0.079837       -0.147452    0.642043
# 2012-01-01 01:00:00   -0.026126       -0.095339       -0.155727    0.642043
# 2012-01-01 02:00:00   -0.026126       -0.088709       -0.160645    0.642043
# 2012-01-01 03:00:00   -0.026126       -0.086564       -0.160405    0.642043
# 2012-01-01 04:00:00   -0.026126       -0.074573       -0.161604    0.642043
#
#                      prod_gen_44  prod_gen_25  export_node_170  prod_gen_35
# time
# 2012-01-01 00:00:00     -0.01686     0.631398         0.110351    -0.087898
# 2012-01-01 01:00:00     -0.01686     0.631398         0.133900    -0.087898
# 2012-01-01 02:00:00     -0.01686     0.631398         0.155408    -0.087898
# 2012-01-01 03:00:00     -0.01686     0.631398         0.181446    -0.087898
# 2012-01-01 04:00:00     -0.01686     0.631398         0.192199    -0.087898
#
# Critical data
#                      flow_89_94  flow_20_23  flow_49_64  flow_101_532  \
# Time
# 2012-01-01 00:00:00    0.031377   -0.082828    0.005335     -0.205127
# 2012-01-01 01:00:00    0.027490   -0.085152    0.007986     -0.199627
# 2012-01-01 02:00:00    0.001342   -0.086240   -0.003567     -0.231931
# 2012-01-01 03:00:00   -0.031362   -0.073259   -0.008111     -0.254105
# 2012-01-01 04:00:00   -0.050811   -0.068240   -0.031840     -0.319747
#
#                      flow_26_28  flow_172_176  flow_122_130  flow_105_116  \
# Time
# 2012-01-01 00:00:00   -0.022461      0.107689      0.351107     -0.080687
# 2012-01-01 01:00:00   -0.021420      0.095639      0.353378     -0.074386
# 2012-01-01 02:00:00    0.048634      0.087674      0.360285     -0.084170
# 2012-01-01 03:00:00    0.067800      0.046904      0.170186     -0.136361
# 2012-01-01 04:00:00    0.062560      0.034748      0.140786     -0.135431
#
#                      flow_193_194  flow_187_191
# Time
# 2012-01-01 00:00:00      0.064689     -0.041436
# 2012-01-01 01:00:00      0.050959     -0.070484
# 2012-01-01 02:00:00      0.044492     -0.095926
# 2012-01-01 03:00:00      0.047072     -0.114989
# 2012-01-01 04:00:00      0.045689     -0.123919
#
# Field data after N/A dropped:
#                      load_node_153  prod_gen_12  renew_node_24  prod_gen_31  \
# time
# 2012-01-01 00:00:00      -0.177899    -0.140735      -0.143126     0.649443
# 2012-01-01 01:00:00      -0.243296    -0.140735      -0.145682     0.649443
# 2012-01-01 02:00:00      -0.302242    -0.140735      -0.148648     0.649443
# 2012-01-01 03:00:00      -0.343224    -0.140735      -0.161940     0.649443
# 2012-01-01 04:00:00      -0.360383    -0.140735      -0.171040     0.649443
#
#                      export_node_108  prod_gen_34  prod_gen_22  prod_gen_29  \
# time
# 2012-01-01 00:00:00        -0.042117     0.647768     0.631226     0.650876
# 2012-01-01 01:00:00        -0.046702     0.647768     0.631226     0.650876
# 2012-01-01 02:00:00        -0.045351     0.647768     0.631226     0.650876
# 2012-01-01 03:00:00        -0.035143     0.647768     0.631226     0.650876
# 2012-01-01 04:00:00        -0.010547     0.647768     0.631226     0.650876
#
#                      load_node_16  prod_gen_2  renew_node_143  renew_node_153  \
# time
# 2012-01-01 00:00:00     -0.033708   -0.026126       -0.079837       -0.147452
# 2012-01-01 01:00:00     -0.073562   -0.026126       -0.095339       -0.155727
# 2012-01-01 02:00:00     -0.119932   -0.026126       -0.088709       -0.160645
# 2012-01-01 03:00:00     -0.192934   -0.026126       -0.086564       -0.160405
# 2012-01-01 04:00:00     -0.249650   -0.026126       -0.074573       -0.161604
#
#                      prod_gen_7  prod_gen_44  prod_gen_25  export_node_170  \
# time
# 2012-01-01 00:00:00    0.642043     -0.01686     0.631398         0.110351
# 2012-01-01 01:00:00    0.642043     -0.01686     0.631398         0.133900
# 2012-01-01 02:00:00    0.642043     -0.01686     0.631398         0.155408
# 2012-01-01 03:00:00    0.642043     -0.01686     0.631398         0.181446
# 2012-01-01 04:00:00    0.642043     -0.01686     0.631398         0.192199
#
#                      prod_gen_35
# time
# 2012-01-01 00:00:00    -0.087898
# 2012-01-01 01:00:00    -0.087898
# 2012-01-01 02:00:00    -0.087898
# 2012-01-01 03:00:00    -0.087898
# 2012-01-01 04:00:00    -0.087898
#
# Columns removed in field data:
# ['prod_gen_14', 'prod_gen_1', 'prod_gen_49']

# %% [markdown]
# ## Linear regression
#
# We have implemented a simple linear regression to apply to your data.
# You should use this as a benchmark for your neural network below.

# %%
# The code below implements a linear regression on your data and compares predicted and true values.
# On the plots there is a red square indicating the areas corresponding to false negatives.
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(fdata['raw'],cdata['fixed'])

y_pred = lm.predict(fdata['raw'])
for index in range(10):
    plt.figure()
    plt.fill_between([0.95, cdata['fixed'].iloc[:,index].max()], [0.95, 0.95], color='r', alpha=0.2)
    plt.plot(cdata['fixed'].iloc[:,index],y_pred[:,index],'.')
    error = score_func(y_pred[:,index],cdata['fixed'].iloc[:,index])
    plt.title('{0}, Error: {1:.04f}'.format(cdata['fixed'].columns[index], error))
    plt.xlabel('True Value')

plt.ylabel('Predicted Value')
print('Overall error: {0:.04f}'.format(score_func(y_pred, cdata['fixed'])))
# Out:
# Overall error: 31681.2995

# %% [markdown]
# **Q#6** Would you recommend using Linear Regression for estimating line criticality indices? Why/why not?

# %% [markdown]
# # Neural Network
#
# You should now produce a neural network that can estimate criticality indices.
# Split your data into a training and test set, build your neural network below, and use the score_func defined above to estimate your model quality.

# %% [markdown]
# **Q#7** Explain why you chose the layers, nodes and activation functions you did. (No wrong answers, we want to know your thought process!) What is the best score you can get with a single layer?

# %%
from sklearn.model_selection import train_test_split

# size of dataset to use for test (rest is used for training)
testdata_size = 1/4

# Raw data
X = fdata['std']
Y = cdata['std']
# Raw data split into 3/4 train data and 1/4 test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=testdata_size)


print("Splitting dataset\n\nInput data:\nOverall size:\t\t{}\nTrain partition:\t{}\nTest partition:\t\t{}".format(len(X), len(X_train), len(X_test)))
print("\n\nOutput data:\nOverall size:\t\t{}\nTrain partition:\t{}\nTest partition:\t\t{}".format(len(Y), len(Y_train), len(Y_test)))
# Out:
# Splitting dataset
#
# Input data:
# Overall size:		8311
# Train partition:	6233
# Test partition:		2078
#
#
# Output data:
# Overall size:		8311
# Train partition:	6233
# Test partition:		2078

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers


model = Sequential()
model.add(Dense(10, input_shape=(20,))) # Input layer (10 nodes)
model.add(Activation('relu'))
model.add(Dense(10)) # First hidden layer (10 nodes)
model.add(Activation('relu'))

adam = optimizers.Adam(lr=0.001, 
                       beta_1=0.9, 
                       beta_2=0.999, 
                       epsilon=1e-08, 
                       decay=0.0)

model.compile(loss='mean_squared_error', optimizer=adam)

model.fit(X_train.values, Y_train.values, epochs = 100, batch_size=500, shuffle=False)
y_pred = model.predict(X_test.values, batch_size = 1000)
# Out:
# Epoch 1/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 2/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 3/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 4/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 5/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 6/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 7/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 8/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 9/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 10/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 11/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 12/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 13/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 14/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 15/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 16/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 17/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 18/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 19/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 20/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 21/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 22/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 23/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 24/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 25/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 26/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 27/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 28/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 29/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 30/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 31/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 32/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 33/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 34/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 35/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 36/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 37/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 38/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 39/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 40/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 41/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 42/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 43/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 44/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 45/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 46/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 47/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 48/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 49/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 50/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 51/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 52/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 53/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 54/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 55/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 56/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 57/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 58/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 59/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 60/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 61/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 62/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 63/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 64/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 65/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 66/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 67/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 68/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 69/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 70/100
# 6233/6233 [==============================] - ETA: 0s - loss: n - 0s - loss: nan
# Epoch 71/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 72/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 73/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 74/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 75/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 76/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 77/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 78/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 79/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 80/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 81/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 82/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 83/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 84/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 85/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 86/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 87/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 88/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 89/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 90/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 91/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 92/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 93/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 94/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 95/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 96/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 97/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 98/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 99/100
# 6233/6233 [==============================] - 0s - loss: nan
# Epoch 100/100
# 6233/6233 [==============================] - 0s - loss: nan

# %% [markdown]
# # K-fold cross validation

# %% [markdown]
# To ensure that your neural network actually works when presented with new data, take the neural network you defined above, and perform a k-fold cross validation on it.

# %% [markdown]
# **Q#8** Using a test window size of one tenth of your data (ten-fold cross validation), plot a histogram of the output of score_func for the validation. Tweak your neural network to achieve the lowest mean score.H

# %%
# Your k-fold code goes here.

# %% [markdown]
# **Q#9** Are you satisfied with the quality of the final estimator? What would be your recommendation for your boss on this issue?

# %% [markdown]
# # Extra task for 3-person groups
#
# **Q#10** Repeat the process, once reducing to 15 sensors, and once reducing to 25 sensors. The costs to keep these sensors running is directly proportional to the number of sensors used. Does changing the number of sensors used change your conclusion in Q#9?
